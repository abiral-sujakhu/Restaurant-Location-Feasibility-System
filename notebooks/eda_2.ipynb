# %% [markdown]
# ###  Common setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
pd.set_option("display.max_columns", None)

# ---- shared config (identical in EDA1 and EDA2) ----
DATA_PATH = "../data/processed/dataset_labelled_with_score.csv"

FEATURES = [
    "bank_count_500m", "bus_stop_count_500m", "cinema_count_500m",
    "clinic_count_500m", "college_count_500m", "hospital_count_500m",
    "museum_count_500m", "office_count_500m", "parking_space_count_500m",
    "recreation_count_500m", "retail_count_500m", "school_count_500m",
    "temple_count_500m", "competitor_count_500m", "avg_restaurant_rating_500m",
    "avg_review_ratings_500m", "nearest_restaurant_m",
]
TARGET = "feasibility_label"     # Low / Moderate / High
PRESENCE = "label"               # 1 = real restaurant, 0 = background
TIER_ORDER = ["Low", "Moderate", "High"]

df = pd.read_csv(DATA_PATH)
print("shape:", df.shape)
df.head()
# Out:
# shape: (4172, 61)
#                       place_id   latitude  longitude search_area primary_type  \
# 0  ChIJsZ5mY70Z6zkRRBczgL9a8ms  27.699546  85.337687   Baneshwor   restaurant
# 1  ChIJ5SO0EQ0Z6zkRTMnqUebrTqA  27.692262  85.336472   Baneshwor   restaurant
# 2  ChIJTdMmLgAZ6zkR84zXOWwdgPE  27.689064  85.334295   Baneshwor   restaurant
# 3  ChIJ3Ru72S8Z6zkR6JYG3tsYlGk  27.681549  85.341340   Baneshwor   restaurant
# 4  ChIJJbL_SlQZ6zkRFWSjunPmuVU  27.688812  85.334080   Baneshwor   restaurant
#
#   searched_as  label  feasibility_score feasibility_label  cluster  \
# 0  restaurant      1          18.652333          Moderate        0
# 1  restaurant      1          27.954012              High        2
# 2  restaurant      1          37.665885              High        2
# 3  restaurant      1          12.152369               Low        1
# 4  restaurant      1          37.304810              High        2
#
#    bank_count_500m  bank_count_500m_normalized  bank_count_500m_contribution  \
# 0               26                    0.273684                      0.018875
# 1               43                    0.452632                      0.031216
# 2               57                    0.600000                      0.041379
# 3                5                    0.052632                      0.003630
# 4               55                    0.578947                      0.039927
#
#    bus_stop_count_500m  bus_stop_count_500m_normalized  \
# 0                    1                        0.090909
# 1                    4                        0.363636
# 2                    6                        0.545455
# 3                    0                        0.000000
# 4                    6                        0.545455
#
#    bus_stop_count_500m_contribution  cinema_count_500m  \
# 0                          0.007885                  0
# 1                          0.031538                  1
# 2                          0.047307                  3
# 3                          0.000000                  0
# 4                          0.047307                  3
#
#    cinema_count_500m_normalized  cinema_count_500m_contribution  \
# 0                      0.000000                        0.000000
# 1                      0.142857                        0.025274
# 2                      0.428571                        0.075822
# 3                      0.000000                        0.000000
# 4                      0.428571                        0.075822
#
#    clinic_count_500m  clinic_count_500m_normalized  \
# 0                 44                      0.578947
# 1                 46                      0.605263
# 2                 65                      0.855263
# 3                 23                      0.302632
# 4                 66                      0.868421
#
#    clinic_count_500m_contribution  college_count_500m  \
# 0                        0.026628                  22
# 1                        0.027838                  37
# 2                        0.039336                  49
# 3                        0.013919                   6
# 4                        0.039942                  46
#
#    college_count_500m_normalized  college_count_500m_contribution  \
# 0                       0.343750                         0.023808
# 1                       0.578125                         0.040041
# 2                       0.765625                         0.053028
# 3                       0.093750                         0.006493
# 4                       0.718750                         0.049781
#
#    hospital_count_500m  hospital_count_500m_normalized  \
# 0                    9                        0.290323
# 1                   13                        0.419355
# 2                   12                        0.387097
# 3                    4                        0.129032
# 4                   11                        0.354839
#
#    hospital_count_500m_contribution  museum_count_500m  \
# 0                          0.012063                  1
# 1                          0.017424                  1
# 2                          0.016084                  1
# 3                          0.005361                  0
# 4                          0.014744                  1
#
#    museum_count_500m_normalized  museum_count_500m_contribution  \
# 0                      0.027778                         0.00446
# 1                      0.027778                         0.00446
# 2                      0.027778                         0.00446
# 3                      0.000000                         0.00000
# 4                      0.027778                         0.00446
#
#    office_count_500m  office_count_500m_normalized  \
# 0                 54                      0.524272
# 1                 66                      0.640777
# 2                 68                      0.660194
# 3                 66                      0.640777
# 4                 65                      0.631068
#
#    office_count_500m_contribution  parking_space_count_500m  \
# 0                        0.022053                         5
# 1                        0.026953                         6
# 2                        0.027770                         9
# 3                        0.026953                         4
# 4                        0.026545                        10
#
#    parking_space_count_500m_normalized  parking_space_count_500m_contribution  \
# 0                             0.217391                               0.016110
# 1                             0.260870                               0.019332
# 2                             0.391304                               0.028998
# 3                             0.173913                               0.012888
# 4                             0.434783                               0.032220
#
#    recreation_count_500m  recreation_count_500m_normalized  \
# 0                     21                          0.272727
# 1                     16                          0.207792
# 2                     15                          0.194805
# 3                     26                          0.337662
# 4                     15                          0.194805
#
#    recreation_count_500m_contribution  retail_count_500m  \
# 0                            0.009656                 52
# 1                            0.007357                 80
# 2                            0.006897                 66
# 3                            0.011955                 78
# 4                            0.006897                 64
#
#    retail_count_500m_normalized  retail_count_500m_contribution  \
# 0                      0.329114                        0.007984
# 1                      0.506329                        0.012284
# 2                      0.417722                        0.010134
# 3                      0.493671                        0.011976
# 4                      0.405063                        0.009827
#
#    school_count_500m  school_count_500m_normalized  \
# 0                 35                      0.583333
# 1                 40                      0.666667
# 2                 28                      0.466667
# 3                 16                      0.266667
# 4                 27                      0.450000
#
#    school_count_500m_contribution  temple_count_500m  \
# 0                        0.017102                 15
# 1                        0.019545                 13
# 2                        0.013681                  6
# 3                        0.007818                 17
# 4                        0.013193                  7
#
#    temple_count_500m_normalized  temple_count_500m_contribution  \
# 0                      0.144231                        0.010072
# 1                      0.125000                        0.008729
# 2                      0.057692                        0.004029
# 3                      0.163462                        0.011414
# 4                      0.067308                        0.004700
#
#    nearest_restaurant_m  nearest_restaurant_m_normalized  \
# 0             66.357920                         0.015377
# 1              3.883478                         0.000900
# 2             35.022157                         0.008116
# 3              5.217717                         0.001209
# 4             35.022157                         0.008116
#
#    nearest_restaurant_m_contribution  competitor_count_500m  \
# 0                           0.000851                     20
# 1                           0.000050                     44
# 2                           0.000449                     48
# 3                           0.000067                     14
# 4                           0.000449                     47
#
#    competitor_count_500m_normalized  competitor_count_500m_contribution  \
# 0                          0.837398                            0.006476
# 1                          0.642276                            0.004967
# 2                          0.609756                            0.004716
# 3                          0.886179                            0.006854
# 4                          0.617886                            0.004779
#
#    avg_restaurant_rating_500m  avg_restaurant_rating_500m_normalized  \
# 0                    4.265000                               0.183750
# 1                    4.247727                               0.188068
# 2                    4.231250                               0.192187
# 3                    4.371429                               0.157143
# 4                    4.270213                               0.182447
#
#    avg_restaurant_rating_500m_contribution  avg_review_ratings_500m  \
# 0                                 0.002125                87.700000
# 1                                 0.002175               159.477273
# 2                                 0.002222               201.104167
# 3                                 0.001817                83.214286
# 4                                 0.002110               200.893617
#
#    avg_review_ratings_500m_normalized  avg_review_ratings_500m_contribution
# 0                            0.941020                              0.000377
# 1                            0.892192                              0.000357
# 2                            0.863875                              0.000346
# 3                            0.944072                              0.000378
# 4                            0.864018                              0.000346

# %% [markdown]
# ### 1. Compare Feature Means by Class

# %%
class_mean = df.groupby(TARGET)[FEATURES].mean()

print(class_mean)
# Out:
#                    bank_count_500m  bus_stop_count_500m  cinema_count_500m  \
# feasibility_label
# High                     46.441074             4.088681           1.801634
# Low                       4.285458             0.817475           0.078396
# Moderate                 18.607664             2.321168           0.527372
#
#                    clinic_count_500m  college_count_500m  hospital_count_500m  \
# feasibility_label
# High                       36.061844           21.123687            11.953326
# Low                         8.070018            3.743866             3.295631
# Moderate                   26.625304           13.923358             9.142944
#
#                    museum_count_500m  office_count_500m  \
# feasibility_label
# High                       11.192532          63.493582
# Low                         0.400958          16.263914
# Moderate                    2.876521          46.698905
#
#                    parking_space_count_500m  recreation_count_500m  \
# feasibility_label
# High                              10.203034              26.497083
# Low                                1.301017               8.613405
# Moderate                           4.542579              17.149635
#
#                    retail_count_500m  school_count_500m  temple_count_500m  \
# feasibility_label
# High                       90.543757          26.012835          39.509918
# Low                        32.230401           9.734291           7.626571
# Moderate                   67.888686          21.693431          20.091849
#
#                    nearest_restaurant_m  competitor_count_500m  \
# feasibility_label
# High                          76.413473              53.526254
# Low                          241.021561               9.059246
# Moderate                     120.235689              28.875912
#
#                    avg_restaurant_rating_500m  avg_review_ratings_500m
# feasibility_label
# High                                 4.369849               193.744184
# Low                                  4.451185                85.679210
# Moderate                             4.410892               119.333333

# %%
plt.figure(figsize=(18,8))

sns.heatmap(class_mean,
            annot=True,
            cmap="YlGnBu",
            fmt=".1f")

plt.title("Average Feature Values by Feasibility Tier")
plt.show()

# %% [markdown]
# ### 2. Correlation Analysis

# %%
corr = df[FEATURES].corr()

plt.figure(figsize=(14,12))

sns.heatmap(corr,
            cmap="coolwarm",
            center=0)

plt.title("Feature Correlation Heatmap")

plt.show()

# %% [markdown]
# #### Find Highly Correlated Pairs (>0.8)

# %%
corr_matrix = df[FEATURES].corr().abs()

upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

high_corr = (
    upper.stack()
         .reset_index()
         .rename(columns={
             "level_0":"Feature 1",
             "level_1":"Feature 2",
             0:"Correlation"
         })
)

high_corr = high_corr[
    high_corr["Correlation"] > 0.80
].sort_values("Correlation", ascending=False)

print(high_corr)
# Out:
# Empty DataFrame
# Columns: [Feature 1, Feature 2, Correlation]
# Index: []

# %% [markdown]
# ### 3. Class Distribution by Area

# %%
area_table = pd.crosstab(
    df["search_area"],
    df[TARGET]
)

print(area_table)

area_table.plot(
    kind="bar",
    figsize=(12,6)
)

plt.title("Feasibility Tier Distribution by Search Area")

plt.ylabel("Number of Restaurants")

plt.xticks(rotation=45)

plt.show()
# Out:
# feasibility_label        High  Low  Moderate
# search_area
# Baneshwor                  95   87       350
# Bhaktapur durbar square    21  304       193
# Boudha stupa                0  291       220
# Durbar Marg               217   53       135
# Kirtipur                    0  359        66
# Koteshwor                  15  249       137
# New Road                  250  114       153
# Patan durbar square       179  103       234
# Pulchowk                   80  111       156

# %% [markdown]
# ### 4. Spatial Map EDA

# %%
import folium

color_map = {
    "High":"green",
    "Medium":"orange",
    "Low":"red"
}

m = folium.Map(
    location=[
        df.latitude.mean(),
        df.longitude.mean()
    ],
    zoom_start=13
)

for _, row in df.iterrows():

    folium.CircleMarker(
        location=[row.latitude, row.longitude],
        radius=5,
        color=color_map.get(row[TARGET], "blue"),
        fill=True,
        fill_opacity=0.8,
        popup=f"{row['search_area']}<br>{row[TARGET]}"
    ).add_to(m)

m.save("../outputs/feasibility_map.html")

# %% [markdown]
# ### 5. Feature vs Tier Separability (Boxplots)

# %%
for feature in FEATURES:

    plt.figure(figsize=(6,4))

    sns.boxplot(
        x=TARGET,
        y=feature,
        data=df
    )

    plt.title(f"{feature} vs Feasibility Tier")

    plt.show()
