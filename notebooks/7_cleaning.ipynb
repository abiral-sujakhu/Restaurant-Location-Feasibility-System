# %% [markdown]
# ### Load the dataset

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("../data/processed/dataset_final_entropy.csv")

# Display the first 5 rows
df.head()
# Out:
#                       place_id   latitude  longitude search_area  Demand  \
# 0  ChIJsZ5mY70Z6zkRRBczgL9a8ms  27.699546  85.337687   Baneshwor  0.2995
# 1  ChIJ5SO0EQ0Z6zkRTMnqUebrTqA  27.692262  85.336472   Baneshwor  0.4008
# 2  ChIJTdMmLgAZ6zkR84zXOWwdgPE  27.689064  85.334295   Baneshwor  0.4458
# 3  ChIJ3Ru72S8Z6zkR6JYG3tsYlGk  27.681549  85.341340   Baneshwor  0.2319
# 4  ChIJJbL_SlQZ6zkRFWSjunPmuVU  27.688812  85.334080   Baneshwor  0.4351
#
#    Accessibility  Competition  Population  label  Demand_contribution  \
# 0         0.4165       0.4850      0.4712      1             0.189981
# 1         0.4903       0.4213      0.4351      1             0.254239
# 2         0.5682       0.4101      0.4219      1             0.282783
# 3         0.5350       0.4891      0.5552      1             0.147101
# 4         0.5848       0.4088      0.4260      1             0.275996
#
#    Accessibility_contribution  Competition_contribution  \
# 0                    0.048357                  0.055860
# 1                    0.056925                  0.042963
# 2                    0.065969                  0.040695
# 3                    0.062115                  0.056690
# 4                    0.067896                  0.040432
#
#    Population_contribution  feasibility_score  cluster feasibility_label
# 0                 0.157250          45.144791        1              High
# 1                 0.145203          49.932931        1              High
# 2                 0.140798          53.024568        1              High
# 3                 0.185283          45.118830        1              High
# 4                 0.142166          52.649073        1              High

# %%
df.describe()
# Out:
#           latitude    longitude       Demand  Accessibility  Competition  \
# count  4172.000000  4172.000000  4172.000000    4172.000000  4172.000000
# mean     27.691487    85.337263     0.236463       0.396715     0.482614
# std       0.019222     0.040978     0.143550       0.113498     0.108753
# min      27.612834    85.253978     0.000000       0.000000     0.209100
# 25%      27.675552    85.311755     0.126075       0.333725     0.426575
# 50%      27.687821    85.328256     0.226150       0.395950     0.491600
# 75%      27.707763    85.355805     0.329325       0.469125     0.525300
# max      27.748779    85.458855     0.659300       0.757400     1.000000
#
#         Population        label  Demand_contribution  \
# count  4172.000000  4172.000000          4172.000000
# mean      0.364638     0.352828             0.149995
# std       0.200844     0.477907             0.091058
# min       0.000000     0.000000             0.000000
# 25%       0.242200     0.000000             0.079973
# 50%       0.352000     0.000000             0.143453
# 75%       0.475650     1.000000             0.208900
# max       1.000000     1.000000             0.418212
#
#        Accessibility_contribution  Competition_contribution  \
# count                 4172.000000               4172.000000
# mean                     0.046059                  0.055377
# std                      0.013177                  0.022019
# min                      0.000000                  0.000000
# 25%                      0.038746                  0.044031
# 50%                      0.045971                  0.057196
# 75%                      0.054466                  0.064019
# max                      0.087936                  0.160128
#
#        Population_contribution  feasibility_score      cluster
# count              4172.000000        4172.000000  4172.000000
# mean                  0.121688          37.311962     0.858581
# std                   0.067026          14.283425     0.806138
# min                   0.000000           4.102881     0.000000
# 25%                   0.080828          27.123042     0.000000
# 50%                   0.117471          36.724943     1.000000
# 75%                   0.158736          47.718838     2.000000
# max                   0.333723          81.596636     2.000000

# %% [markdown]
# ## Check dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4172 entries, 0 to 4171
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   place_id                    4172 non-null   object
#  1   latitude                    4172 non-null   float64
#  2   longitude                   4172 non-null   float64
#  3   search_area                 4172 non-null   object
#  4   Demand                      4172 non-null   float64
#  5   Accessibility               4172 non-null   float64
#  6   Competition                 4172 non-null   float64
#  7   Population                  4172 non-null   float64
#  8   label                       4172 non-null   int64
#  9   Demand_contribution         4172 non-null   float64
#  10  Accessibility_contribution  4172 non-null   float64
#  11  Competition_contribution    4172 non-null   float64
#  12  Population_contribution     4172 non-null   float64
#  13  feasibility_score           4172 non-null   float64
#  14  cluster                     4172 non-null   int64
#  15  feasibility_label           4172 non-null   object
# dtypes: float64(11), int64(2), object(3)
# memory usage: 521.6+ KB

# %%
df.columns
# Out:
# Index(['place_id', 'latitude', 'longitude', 'search_area', 'Demand',
#        'Accessibility', 'Competition', 'Population', 'label',
#        'Demand_contribution', 'Accessibility_contribution',
#        'Competition_contribution', 'Population_contribution',
#        'feasibility_score', 'cluster', 'feasibility_label'],
#       dtype='object')

# %% [markdown]
# ### Check for missing values

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
print(missing)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Check missing target Values

# %%
print(df["feasibility_label"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ### Validate the target labels

# %%
print(df["feasibility_label"].unique())
# Out:
# ['High' 'Moderate' 'Low']

# %% [markdown]
# ### Check for Duplicate Rows

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# #### Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4172 entries, 0 to 4171
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   place_id                    4172 non-null   object
#  1   latitude                    4172 non-null   float64
#  2   longitude                   4172 non-null   float64
#  3   search_area                 4172 non-null   object
#  4   Demand                      4172 non-null   float64
#  5   Accessibility               4172 non-null   float64
#  6   Competition                 4172 non-null   float64
#  7   Population                  4172 non-null   float64
#  8   label                       4172 non-null   int64
#  9   Demand_contribution         4172 non-null   float64
#  10  Accessibility_contribution  4172 non-null   float64
#  11  Competition_contribution    4172 non-null   float64
#  12  Population_contribution     4172 non-null   float64
#  13  feasibility_score           4172 non-null   float64
#  14  cluster                     4172 non-null   int64
#  15  feasibility_label           4172 non-null   object
# dtypes: float64(11), int64(2), object(3)
# memory usage: 521.6+ KB

# %% [markdown]
# ### Data Validation

# %%
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns

for col in numeric_cols:
    print(f"{col}: Min = {df[col].min()}, Max = {df[col].max()}")
# Out:
# latitude: Min = 27.6128344, Max = 27.7487787
# longitude: Min = 85.2539784, Max = 85.4588553
# Demand: Min = 0.0, Max = 0.6593
# Accessibility: Min = 0.0, Max = 0.7574
# Competition: Min = 0.2091, Max = 1.0
# Population: Min = 0.0, Max = 1.0
# label: Min = 0, Max = 1
# Demand_contribution: Min = 0.0, Max = 0.4182124056736406
# Accessibility_contribution: Min = 0.0, Max = 0.0879357089572091
# Competition_contribution: Min = 0.0, Max = 0.1601284944403444
# Population_contribution: Min = 0.0, Max = 0.3337233909288057
# feasibility_score: Min = 4.102880827189679, Max = 81.596635644285
# cluster: Min = 0, Max = 2
